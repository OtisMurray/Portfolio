# %% [markdown]
# # Purpose

# %% [markdown]
# We made some random forest models to find the specific demographics among students that might be at more risk of certain mental illnesses, like depression, anxiety, and panic attacks. It serves as a way to better find those who might need this app the most, allowing it to be more efficient and helpful to the overall community. While the depression random forest model is reasonable with 81% accuracy, the other models contain lower accuracy in the 60% range. In the future we would introduce more data as these models were built on a very small dataset and hopefully this would drastically increase their accuracies. We know that with a project as serious as this, there is a very thin line between success and failure. It's crucial that we continue to improve this model as the app could mean the difference of saving the life of someone who deals with mental illnesses. Our system will be able to flag whether or not someone should be doing a daily journal and their counselors or advisors can then introduce it to them.

# %%
# Model for Depression
def train_random_forest_for_depression(data, model_path='depression_model.pkl'):
    X = data.drop(columns=['do_you_have_depression'])
    Y = data['do_you_have_depression']

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, Y_train)

    Y_pred = model.predict(X_test)
    print("Depression Model Accuracy: {:.2f}".format(accuracy_score(Y_test, Y_pred)))
    print(classification_report(Y_test, Y_pred))

    # Save the trained model to a file using pickle
    with open(model_path, 'wb') as file:
        pickle.dump(model, file)

    return X_test

# Model for Anxiety
def train_random_forest_for_anxiety(data, model_path='anxiety_model.pkl'):
    X = data.drop(columns=['do_you_have_anxiety'])
    Y = data['do_you_have_anxiety']

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, Y_train)

    Y_pred = model.predict(X_test)
    print("Anxiety Model Accuracy: {:.2f}".format(accuracy_score(Y_test, Y_pred)))
    print(classification_report(Y_test, Y_pred))

    # Save the trained model to a file using pickle
    with open(model_path, 'wb') as file:
        pickle.dump(model, file)

    return X_test

# Model for Panic Attack
def train_random_forest_for_panic_attack(data, model_path='panic_attack_model.pkl'):
    X = data.drop(columns=['do_you_have_panic_attack'])
    Y = data['do_you_have_panic_attack']

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, Y_train)

    Y_pred = model.predict(X_test)
    print("Panic Attack Model Accuracy: {:.2f}".format(accuracy_score(Y_test, Y_pred)))
    print(classification_report(Y_test, Y_pred))

    # Save the trained model to a file using pickle
    with open(model_path, 'wb') as file:
        pickle.dump(model, file)

    return X_test

# Train and evaluate models, and save them to pickle files
print("----- Depression Random Forest -----")
X_test_depression = train_random_forest_for_depression(subsetted_data, model_path='depression_model.pkl')

print("\n----- Anxiety Random Forest -----")
X_test_anxiety = train_random_forest_for_anxiety(subsetted_data, model_path='anxiety_model.pkl')

print("\n----- Panic Attack Random Forest -----")
X_test_panic_attack = train_random_forest_for_panic_attack(subsetted_data, model_path='panic_attack_model.pkl')
# Out:
# ----- Depression Random Forest -----
# Depression Model Accuracy: 0.81
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.80      0.57      0.67         7
#
#     accuracy                           0.81        21
#    macro avg       0.81      0.75      0.77        21
# weighted avg       0.81      0.81      0.80        21
#
#
# ----- Anxiety Random Forest -----
# Anxiety Model Accuracy: 0.62
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75        12
#            1       1.00      0.11      0.20         9
#
#     accuracy                           0.62        21
#    macro avg       0.80      0.56      0.47        21
# weighted avg       0.77      0.62      0.51        21
#
#
# ----- Panic Attack Random Forest -----
# Panic Attack Model Accuracy: 0.62
#               precision    recall  f1-score   support
#
# ...
